# %%
sentences = [
"I am from India. India is the 3rd strongest in military and 1st in the world for population.",
"For clean energy geneartion, government of India have started Solar panel policy, to help reduce the pollution and its good for the enviornment.",

"India is the cultural hub for many sports and tradition.",
"There where many instance for which World Cup T20 series where done in India.",

"India is rapidly emerging as a global AI powerhouse, driven by the IndiaAI Mission which aims to build sovereign compute capacity (38,000+ GPUs), indigenous models, and foster a robust startup ecosystem. Focused on \"AI for All,\" it aims to leverage AI in healthcare, agriculture, and governance, expecting a $126 Bn market by 2030. ",
"As of late February 2026, India's tech landscape is dominated by rapid AI adoption, major semiconductor manufacturing milestones, and new flagship smartphone launches. Key developments include the launch of the AI-powered iQOO 15R, the establishment of the HCL-Foxconn India Chip facility in Noida, and Nvidia's partnership to build an AI Superpark in Bengaluru.",
"The iQOO 15R was launched with a Snapdragon 8 Gen 5 processor and 7,600mAh battery. Realme launched the P4 Lite with a 6,300mAh battery. The Samsung Galaxy S26 series is set to debut, featuring AI-integrated capabilities."
]

# %%
#embedding using TF-IDF approach
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer #TF-Bow
from sklearn.feature_extraction.text import TfidfVectorizer #TFIDF
from sklearn.metrics.pairwise import cosine_similarity

# %%
#embeddingt using TF-Bow approach
tf_vectorizer = CountVectorizer()
tf_matrix = tf_vectorizer.fit_transform(sentences)

# %%
tf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 176 stored elements and shape (7, 135)>

# %%
tf_similarity = cosine_similarity(tf_matrix)
tf_similarity
# Out:
# array([[1.        , 0.36115756, 0.46156633, 0.31277162, 0.2586303 ,
#         0.42971471, 0.24866795],
#        [0.36115756, 1.        , 0.36514837, 0.14433757, 0.21483446,
#         0.33398629, 0.22951012],
#        [0.46156633, 0.36514837, 1.        , 0.23717082, 0.23533936,
#         0.30869745, 0.23570226],
#        [0.31277162, 0.14433757, 0.23717082, 1.        , 0.12403473,
#         0.10846523, 0.0372678 ],
#        [0.2586303 , 0.21483446, 0.23533936, 0.12403473, 1.        ,
#         0.37669676, 0.20339007],
#        [0.42971471, 0.33398629, 0.30869745, 0.10846523, 0.37669676,
#         1.        , 0.33954988],
#        [0.24866795, 0.22951012, 0.23570226, 0.0372678 , 0.20339007,
#         0.33954988, 1.        ]])

# %%
#embeddingt using Tfidf-Bow approach
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)

tfidf_matrix

tfidf_similarity = cosine_similarity(tfidf_matrix)
tfidf_similarity
# Out:
# array([[1.        , 0.14585158, 0.20400199, 0.17911789, 0.11177592,
#         0.1970435 , 0.09263886],
#        [0.14585158, 1.        , 0.14122258, 0.05268949, 0.08167347,
#         0.16302264, 0.07736193],
#        [0.20400199, 0.14122258, 1.        , 0.13899995, 0.08681232,
#         0.11720413, 0.08333384],
#        [0.17911789, 0.05268949, 0.13899995, 1.        , 0.06354896,
#         0.04639471, 0.03298098],
#        [0.11177592, 0.08167347, 0.08681232, 0.06354896, 1.        ,
#         0.22072405, 0.08954557],
#        [0.1970435 , 0.16302264, 0.11720413, 0.04639471, 0.22072405,
#         1.        , 0.15596634],
#        [0.09263886, 0.07736193, 0.08333384, 0.03298098, 0.08954557,
#         0.15596634, 1.        ]])

# %%
#finding document similarity

def doc_sim(similarity_matrix,sentences):
  for i in range(len(sentences)):
    sims = similarity_matrix[i].copy()
    sims[i]=-1
    top_index = np.argmax(sims)
    print(sentences[i], "   --->   ", sentences[top_index])

# %%
doc_sim(tfidf_similarity,sentences)
# Out:
# I am from India. India is the 3rd strongest in military and 1st in the world for population.    --->    India is the cultural hub for many sports and tradition.
# For clean energy geneartion, government of India have started Solar panel policy, to help reduce the pollution and its good for the enviornment.    --->    As of late February 2026, India's tech landscape is dominated by rapid AI adoption, major semiconductor manufacturing milestones, and new flagship smartphone launches. Key developments include the launch of the AI-powered iQOO 15R, the establishment of the HCL-Foxconn India Chip facility in Noida, and Nvidia's partnership to build an AI Superpark in Bengaluru.
# India is the cultural hub for many sports and tradition.    --->    I am from India. India is the 3rd strongest in military and 1st in the world for population.
# ...
